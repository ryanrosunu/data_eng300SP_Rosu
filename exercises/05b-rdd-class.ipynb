# %% [markdown]
# # Resilient distributed datasets
# Resilient distributed datasets, or *RDD*s, are the fundamental blocks in PySpark.

# %% [markdown]
# ## What is RDD?
# RDD is essentially a collection of unordered objects,
# - or a mathematical *set*,
# - or a Python list of objects,
# - or similar to a JSON.

# %% [markdown]
# |![rdd-idea](../img/rdd-idea.png)|![math-set](../img/math-set.png)|![json-ex](../img/json-ex.png)|
# | |Fig. Collection of objects| |

# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-4.1.1.tar.gz (455.4 MB)
#      ---------------------------------------- 0.0/455.4 MB ? eta -:--:--
#       -------------------------------------- 6.0/455.4 MB 30.7 MB/s eta 0:00:15
#      - ------------------------------------ 13.9/455.4 MB 34.9 MB/s eta 0:00:13
#      - ------------------------------------ 19.9/455.4 MB 32.3 MB/s eta 0:00:14
#      -- ----------------------------------- 27.0/455.4 MB 32.3 MB/s eta 0:00:14
#      -- ----------------------------------- 33.8/455.4 MB 32.0 MB/s eta 0:00:14
#      --- ---------------------------------- 40.4/455.4 MB 31.7 MB/s eta 0:00:14
#      --- ---------------------------------- 47.2/455.4 MB 31.9 MB/s eta 0:00:13
#      ---- --------------------------------- 52.4/455.4 MB 30.9 MB/s eta 0:00:14
#      ---- --------------------------------- 56.6/455.4 MB 29.8 MB/s eta 0:00:14
#      ----- -------------------------------- 62.7/455.4 MB 29.6 MB/s eta 0:00:14
#      ----- -------------------------------- 67.1/455.4 MB 28.9 MB/s eta 0:00:14
#      ------ ------------------------------- 72.1/455.4 MB 28.4 MB/s eta 0:00:14
#      ------ ------------------------------- 77.1/455.4 MB 28.1 MB/s eta 0:00:14
#      ------ ------------------------------- 81.5/455.4 MB 27.5 MB/s eta 0:00:14
#      ------- ------------------------------ 86.2/455.4 MB 27.1 MB/s eta 0:00:14
#      ------- ------------------------------ 92.0/455.4 MB 27.1 MB/s eta 0:00:14
#      -------- ----------------------------- 97.8/455.4 MB 27.0 MB/s eta 0:00:14
#      -------- ---------------------------- 103.3/455.4 MB 27.0 MB/s eta 0:00:14
#      -------- ---------------------------- 108.8/455.4 MB 27.0 MB/s eta 0:00:13
#      --------- --------------------------- 113.5/455.4 MB 26.7 MB/s eta 0:00:13
#      --------- --------------------------- 119.3/455.4 MB 26.7 MB/s eta 0:00:13
#      ---------- -------------------------- 124.8/455.4 MB 26.7 MB/s eta 0:00:13
#      ---------- -------------------------- 129.0/455.4 MB 26.4 MB/s eta 0:00:13
#      ---------- -------------------------- 135.0/455.4 MB 26.5 MB/s eta 0:00:13
#      ----------- ------------------------- 141.6/455.4 MB 26.7 MB/s eta 0:00:12
#      ----------- ------------------------- 147.1/455.4 MB 26.6 MB/s eta 0:00:12
#      ------------ ------------------------ 153.4/455.4 MB 26.7 MB/s eta 0:00:12
#      ------------ ------------------------ 158.1/455.4 MB 26.5 MB/s eta 0:00:12
#      ------------- ----------------------- 160.2/455.4 MB 26.0 MB/s eta 0:00:12
#      ------------- ----------------------- 164.1/455.4 MB 25.7 MB/s eta 0:00:12
#      ------------- ----------------------- 169.3/455.4 MB 25.6 MB/s eta 0:00:12
#      -------------- ---------------------- 173.8/455.4 MB 25.5 MB/s eta 0:00:12
#      -------------- ---------------------- 179.0/455.4 MB 25.5 MB/s eta 0:00:11
#      --------------- --------------------- 185.3/455.4 MB 25.6 MB/s eta 0:00:11
#      --------------- --------------------- 191.9/455.4 MB 25.7 MB/s eta 0:00:11
#      ---------------- -------------------- 197.1/455.4 MB 25.7 MB/s eta 0:00:11
#      -------------------------------- ---- 395.1/455.4 MB 22.1 MB/s eta 0:00:03
#      -------------------------------- ---- 401.3/455.4 MB 22.2 MB/s eta 0:00:03
#      --------------------------------- --- 407.1/455.4 MB 22.2 MB/s eta 0:00:03
#      --------------------------------- --- 412.9/455.4 MB 22.1 MB/s eta 0:00:02
#      --------------------------------- --- 415.0/455.4 MB 21.9 MB/s eta 0:00:02
#      --------------------------------- --- 417.3/455.4 MB 21.7 MB/s eta 0:00:02
#      --------------------------------- --- 418.4/455.4 MB 21.4 MB/s eta 0:00:02
#      ---------------------------------- -- 420.2/455.4 MB 21.2 MB/s eta 0:00:02
#      ---------------------------------- -- 421.8/455.4 MB 21.1 MB/s eta 0:00:02
#      ---------------------------------- -- 426.2/455.4 MB 21.2 MB/s eta 0:00:02
#      ----------------------------------- - 431.8/455.4 MB 21.2 MB/s eta 0:00:02
#      ----------------------------------- - 436.7/455.4 MB 21.2 MB/s eta 0:00:01
#      ----------------------------------- - 442.8/455.4 MB 21.2 MB/s eta 0:00:01
#      ------------------------------------  448.5/455.4 MB 21.2 MB/s eta 0:00:01
#      ------------------------------------  453.0/455.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------  455.3/455.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------  455.3/455.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------  455.3/455.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------  455.3/455.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------  455.3/455.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------  455.3/455.4 MB 21.1 MB/s eta 0:00:01
#      ------------------------------------  455.3/455.4 MB 21.1 MB/s eta 0:00:01
#      ---------------------------------------- 455.4/455.4 MB 18.7 MB/s  0:00:21
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting py4j<0.10.9.10,>=0.10.9.7 (from pyspark)
#   Downloading py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (pyproject.toml): started
#   Building wheel for pyspark (pyproject.toml): still running...
#   Building wheel for pyspark (pyproject.toml): still running...
#   Building wheel for pyspark (pyproject.toml): finished with status 'done'
#   Created wheel for pyspark: filename=pyspark-4.1.1-py2.py3-none-any.whl size=456008747 sha256=3d18653a26c9119098c2cefe88f29495b34df5c95eae3f134efaf7f46ad53256
#   Stored in directory: c:\users\tziga\appdata\local\pip\cache\wheels\16\77\d3\d15aaaab1df8384ad9bd94caba26a1a5aa439d8afd187a5ab9
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
#
#    ---------------------------------------- 0/2 [py4j]
#    ---------------------------------------- 0/2 [py4j]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    ---------------------------------------- 2/2 [pyspark]
#
# Successfully installed py4j-0.10.9.9 pyspark-4.1.1

# %%
# set up an RDD
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('rddExample').getOrCreate()

# list promoted to RDD

# %% [markdown]
# ## Why RDD if we have dataframes?
# - If the data at hand are more *freeformed*, using an RDD allows for storage of various types of objects.
# - Compared to dataframe, which will *attempt* (and fail) to find a common denominator to fit the data above.

# %% [markdown]
# ## Main ingredients of RDD manipulation
# We cover three main building blocks for using RDDs, inheriting the concept of a MapReduce scheme.

# %% [markdown]
# Each of the following building blocks (*functions*) takes a functional input:
# - `map()`
# - `filter()`
# - `reduce()`

# %% [markdown]
# ### `map` through an example
# `map()` applies the given function to each element of the RDD.

# %%
# simple mapping function

# %%
# mapping to the RDD

# %% [markdown]
# **Quick note:**
# - Why did the line throw an error?
# - When was the error thrown?

# %% [markdown]
# **A potential fix:**

# %%
from py4j.protocol import Py4JJavaError

def safer_add_one(value):
    pass # ...

# %% [markdown]
# **Lesson here**:
# - PySpark does not warn you about the content of the RDD.
# - As the developer, we are responsible for how to deal with the data given to an RDD.

# %% [markdown]
# ### `filter` through an example
# `filter()` takes a function that returns `True`/`False` based on any conditions.

# %%
# writing a filtering example

# %% [markdown]
# ### `reduce` through an example
# `reduce()` summarizes the RDD by sequentially applying the given function.
# - similar to `groupby()` in a dataframe.

# %%
# create a new RDD

# example using reduce

# %% [markdown]
# **Warnings about `reduce()`**
# - What functions are reasonable for `reduce()`?
# - *commutative operation*
# - *associative operation*

# %% [markdown]
# **Additional Note:**
#
# A dataframe is actually an RDD, e.g.,

# %%
# Dataframe creation
